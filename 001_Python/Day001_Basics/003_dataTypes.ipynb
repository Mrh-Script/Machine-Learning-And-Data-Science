# %% [markdown]
# ## 1. Basic Data Types
# - Integers
# - Floating - point numbers
# - Strings
# - Booleans
#
# ## 2. Advanced Data Types
# - Lists
# - Tuples
# - Sets
# - Dictionaries

# %%
## Integer DataTypes

age = 25
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
## Floaing point DataTypes

bmi = 18.7
print(bmi)
print(type(bmi))
# Out:
# 18.7
# <class 'float'>

# %%
## String DataTypes
name = "Mrh"
print(name)
print(type(name))
# Out:
# Mrh
# <class 'str'>

# %%
## Boolen DataTypes

a = 10
b = 10

print(a==b)
print(type(a==b))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ## 3. Concatanation & It's Errors
# - Same dataTyped values / variables can be attached

# %%
## Error concatanation

word = "Hello" + 4
print(word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 ## Error concatanation
#       2
# ----> 3 word = "Hello" + 4
#       4 print(word)
#
# TypeError: can only concatenate str (not "int") to str

# %%
## Valid concatanation

word = "Hello" + str(4)
print(word)
# Out:
# Hello4
