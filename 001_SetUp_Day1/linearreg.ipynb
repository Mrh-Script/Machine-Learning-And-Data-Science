# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 3.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.3 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.3 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.3 MB 2.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.3 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.3 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.3 MB 1.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.3 MB 1.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/11.3 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 3.4/11.3 MB 1.6 MB/s eta 0:00:06
# ...

# %%
1+1
# Out:
# 2
